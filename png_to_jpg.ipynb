# %%
import numpy as np
import PIL
from PIL import Image 
import glob

# %%
load_path_abstract = '/Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/*.png' 
save_path_abstract = '/Users/jordankruguer/Desktop/neuro-140/140-data/processed-data/abstract/'

load_path_line = '/Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/*.png' 
save_path_line = '/Users/jordankruguer/Desktop/neuro-140/140-data/processed-data/line/'

load_path_target = '/Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/*.png' 
save_path_target = '/Users/jordankruguer/Desktop/neuro-140/140-data/processed-data/target/'

# %%
# CONVERT: ABSTRACT
for filename in glob.glob(load_path_abstract):
    print(filename)
    img = Image.open(filename)
    rgb_img = img.convert('RGB')
    filename = filename[:-4] # Strip .png
    filename = filename + '.jpg'
    rgb_img.save(filename)
# Out:
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/castle-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/fduomo-1__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/westminster-2__trans-10_0.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/vessel-2__flipv.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/eiffel-2__rot90.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/palais-1 copy__trans-10_0.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/empire-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/vecchio-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/burj-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/burjkal-1__blur1.5.jpg
# ...

# %%
# CONVERT: LINE
for filename in glob.glob(load_path_line):
    print(filename)
    img = Image.open(filename)
    rgb_img = img.convert('RGB')
    filename = filename[:-4] # Strip .png
    filename = filename + '.jpg'
    rgb_img.save(filename)
# Out:
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/defense-1__rot-45.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/Triomphe-1__blur1.5.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/Triomphe-3__rot90.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/burj-2.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/basil-3__fliph.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/sacre-3__fliph.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/burjkal-3__trans20_10.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/cap-2__fliph.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/Battersea-3__trans-10_0.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/chrylser-1__noise0.01.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/seagram-3__flipv.png
# ...

# %%
# CONVERT: TARGET
for filename in glob.glob(load_path_target):
    print(filename)
    img = Image.open(filename)
    rgb_img = img.convert('RGB')
    filename = filename[:-4] # Strip .png
    filename = filename + '.jpg'
    rgb_img.save(filename)
# Out:
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-2__noise0.01.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-2__noise0.5.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-3__fliph.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-3__rot90.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-1__rot-45.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-2__trans20_10.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-3__noise0.01.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-1__trans-10_0.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-1__noise0.5.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-1__noise0.01.png
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/alamo-2__rot-45.png
# ...
