# %%
import numpy as np
import PIL
from PIL import Image 
import glob

# %%
load_path = '/Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/*' 
save_path = '/Users/jordankruguer/Desktop/neuro-140/140-data/processed-data/target/'

# %%
load_path_abstract = '/Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/*.jpg' 
save_path_abstract = '/Users/jordankruguer/Desktop/neuro-140/140-data/processed-data/abstract/'

load_path_line = '/Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/*.jpg' 
save_path_line = '/Users/jordankruguer/Desktop/neuro-140/140-data/processed-data/line/'

load_path_target = '/Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/*.jpg' 
save_path_target = '/Users/jordankruguer/Desktop/neuro-140/140-data/processed-data/target/'

# %%
for filename in glob.glob(load_path_abstract):
    print(filename)
    img = Image.open(filename)
    img = img.resize((256,256))
    img.save(filename)
# Out:
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/castle-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/fduomo-1__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/westminster-2__trans-10_0.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/vessel-2__flipv.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/eiffel-2__rot90.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/palais-1 copy__trans-10_0.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/empire-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/vecchio-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/burj-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/abstract/burjkal-1__blur1.5.jpg
# ...

# %%
for filename in glob.glob(load_path_line):
    print(filename)
    img = Image.open(filename)
    img = img.resize((256,256))
    img.save(filename)
# Out:
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/castle-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/fduomo-1__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/vessel-2__flipv.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/eiffel-2__rot90.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/empire-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/vecchio-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/burj-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/burjkal-1__blur1.5.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/sydney-3__trans-10_0.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/trin-2__fliph.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/line/cathbras-1__noise0.5.jpg
# ...

# %%
for filename in glob.glob(load_path_target):
    print(filename)
    img = Image.open(filename)
    img = img.resize((256,256))
    img.save(filename)
# Out:
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/castle-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/fduomo-1__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/westminster-2__trans-10_0.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/vessel-2__flipv.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/eiffel-2__rot90.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/empire-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/vecchio-1__trans20_10.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/burj-3__noise0.01.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/burjkal-1__blur1.5.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/sydney-3__trans-10_0.jpg
# /Users/jordankruguer/Desktop/neuro-140/140-data/raw-data/target/trin-2__fliph.jpg
# ...
